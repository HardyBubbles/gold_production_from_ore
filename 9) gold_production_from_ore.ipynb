# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек-и-загрузка-данных" data-toc-modified-id="Импорт-библиотек-и-загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек и загрузка данных</a></span></li><li><span><a href="#Оценка-имеющихся-данных" data-toc-modified-id="Оценка-имеющихся-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Оценка имеющихся данных</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Дубликаты</a></span></li><li><span><a href="#Пропуски-в-данных" data-toc-modified-id="Пропуски-в-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Пропуски в данных</a></span></li><li><span><a href="#Проверка-правильности-расчёта-эффективности-обогащения" data-toc-modified-id="Проверка-правильности-расчёта-эффективности-обогащения-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверка правильности расчёта эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков-в-обучающей-и-тестовой-выборках" data-toc-modified-id="Анализ-признаков-в-обучающей-и-тестовой-выборках-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Анализ признаков в обучающей и тестовой выборках</a></span></li><li><span><a href="#Определение-ключевых-признаков-для-обучения-модели-и-их-подготовка" data-toc-modified-id="Определение-ключевых-признаков-для-обучения-модели-и-их-подготовка-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Определение ключевых признаков для обучения модели и их подготовка</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-концентрации-Au,-Ag,-Pb-на-разных-этапах-очистки" data-toc-modified-id="Анализ-концентрации-Au,-Ag,-Pb-на-разных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ концентрации Au, Ag, Pb на разных этапах очистки</a></span></li><li><span><a href="#Сравнение-распределения-размеров-гранул-сырья" data-toc-modified-id="Сравнение-распределения-размеров-гранул-сырья-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравнение распределения размеров гранул сырья</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Разработка-модели" data-toc-modified-id="Разработка-модели-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Разработка модели</a></span><ul class="toc-item"><li><span><a href="#Подготовка-пространства-признаков-и-целевого-признака-на-основе-выборок" data-toc-modified-id="Подготовка-пространства-признаков-и-целевого-признака-на-основе-выборок-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подготовка пространства признаков и целевого признака на основе выборок</a></span></li><li><span><a href="#Выбор-модели-и-оптимизация-гиперпараметров" data-toc-modified-id="Выбор-модели-и-оптимизация-гиперпараметров-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выбор модели и оптимизация гиперпараметров</a></span></li><li><span><a href="#Проверка-на-вменяемость" data-toc-modified-id="Проверка-на-вменяемость-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка на вменяемость</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# **Общее описание**
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.
#
# **Технологический процесс**
# Технологический процесс представляет из себя постепенное преобразование смеси золотоносной руды в финальный концентрат.
# Руда -> Смесь золотоносной руды -> Черновой концентрат -> Первый этап очистки -> Второй этап очистки -> Финальный концентрат
# *Описание стадий процесса:*
#   1. Первичная обрботка;
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
#   2. Флотация;
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#   3. Очистка.
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
# Если быть точным, то отвальные хвосты получается при каждом переходе с этапа на этап.
#
# **Описание данных**
# Технологический процесс
#
#     Rougher feed — исходное сырье
#     Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#         Xanthate — ксантогенат (промотер, или активатор флотации);
#         Sulphate — сульфат (на данном производстве сульфид натрия);
#         Depressant — депрессант (силикат натрия).
#     Rougher process (англ. «грубый процесс») — флотация
#     Rougher tails — отвальные хвосты
#     Float banks — флотационная установка
#     Cleaner process — очистка
#     Rougher Au — черновой концентрат золота
#     Final Au — финальный концентрат золота
#
# **Параметры этапов**
#
#     air amount — объём воздуха
#     fluid levels — уровень жидкости
#     feed size — размер гранул сырья
#     feed rate — скорость подачи
#
# Наименование признаков
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
# Возможные значения для блока [этап]:
#
#     rougher — флотация
#     primary_cleaner — первичная очистка
#     secondary_cleaner — вторичная очистка
#     final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
#
#     input — параметры сырья
#     output — параметры продукта
#     state — параметры, характеризующие текущее состояние этапа
#     calculation — расчётные характеристики
#
# **Метрика качества**
# Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
# Нужно спрогнозировать сразу две величины:
#
#   * эффективность обогащения чернового концентрата `rougher.output.recovery`;
#   * эффективность обогащения финального концентрата `final.output.recovery`.
#
# Итоговая метрика складывается из двух величин:
# sMAPE = 25% * sMAPE(rougher) + 75% * sMAPE(final)
#
# **Ход выполнения**
# 1. Подготовить данные
#     1.1. Открыть файлы и изучите их.
#     Путь к файлам:
#
#         /datasets/gold_recovery_train_new.csv
#         /datasets/gold_recovery_test_new.csv
#         /datasets/gold_recovery_full_new.csv
#
#     1.2. Проверить, что эффективность обогащения рассчитана правильно:
#         1.2.1 Вычислиь её на обучающей выборке для признака `rougher.output.recovery`.
#         1.2.2 Найти MAE между вашими расчётами и значением признака.
#         1.2.3 Опишите выводы.
#
#     1.3. Проанализировать признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
#     1.4. Провести предобработку данных.
#
# 2. Проанализируйте данные
#     2.1. Посмотреть, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Описать выводы.
#     2.2. Сравнить распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#     2.3. Исследовать суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
# 3. Построить модель
#     3.1. Написать функцию для вычисления итоговой sMAPE.
#     3.2. Обучить разные модели и оцените их качество кросс-валидацией. Выбрать лучшую модель и проверить её на тестовой выборке.
#     3.3 Описать выводы.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Импорт библиотек и загрузка данных

# %% [markdown]
# Каждый проект начинается с импорта необходимых модулей и библиотек.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import make_scorer
from sklearn.pipeline import  make_pipeline
from sklearn.impute import KNNImputer
from sklearn.dummy import DummyRegressor

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
# подгружаем данные
pth0_1 = '/datasets/gold_recovery_train_new.csv'
pth0_2 = 'C:/Users/username/Desktop/gold_recovery_train_new.csv.csv'

pth1_1 = '/datasets/gold_recovery_test_new.csv'
pth1_2 = 'C:/Users/username/Desktop/gold_recovery_test_new.csv'

pth2_1 = '/datasets/gold_recovery_full_new.csv'
pth2_2 = 'C:/Users/username/Desktop/gold_recovery_full_new.csv'

if os.path.exists(pth0_1):
    data_train = pd.read_csv(pth0_1)
elif os.path.exists(pth0_2):
    data_train = pd.read_csv(pth0_2)
else:
    print('Check the PATH to data_0 file please')

if os.path.exists(pth1_1):
    data_test = pd.read_csv(pth1_1)
elif os.path.exists(pth1_2):
    data_test = pd.read_csv(pth1_2)
else:
    print('Check the PATH to data_1 file please')
    
if os.path.exists(pth2_1):
    data_full = pd.read_csv(pth2_1)
elif os.path.exists(pth2_2):
    data_full = pd.read_csv(pth2_2)
else:
    print('Check the PATH to data_2 file please')

# %% [markdown]
# ### Оценка имеющихся данных

# %% [markdown]
# Применив методы `head(), describe(), info()` к полученным наборам данных, получим первичную информацию о них.

# %%
data_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
data_train.describe()
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 14148.000000                 14148.000000
# mean                      5.142034                    10.132960
# std                       1.369586                     1.654930
# min                       0.000000                     0.000000
# 25%                       4.211620                     9.297355
# 50%                       4.994652                    10.297144
# 75%                       5.859540                    11.170603
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  13938.000000                 14149.000000
# mean                       9.202849                    44.003792
# std                        2.790516                     4.905261
# min                        0.000000                     0.000000
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
data_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
data_test.describe()
# Out:
#        primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# count                    5286.000000                       5285.000000
# mean                      174.839652                          8.683596
# std                        43.027080                          3.072050
# min                         2.566156                          0.003839
# 25%                       147.121401                          6.489555
# 50%                       177.828489                          8.052207
# 75%                       208.125438                         10.027764
# max                       265.983123                         40.000000
#
#        primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# count                      5290.000000                     5286.000000
# mean                          7.266339                        1.383803
# std                           0.610219                        0.643474
# ...

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
data_full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
data_full.describe()
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 19438.000000                 19438.000000
# mean                      5.168470                     9.978895
# std                       1.372348                     1.669240
# min                       0.000000                     0.000000
# 25%                       4.251240                     9.137262
# 50%                       5.066094                    10.102433
# 75%                       5.895527                    11.035769
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  19228.000000                 19439.000000
# mean                       9.501224                    44.076513
# std                        2.787537                     5.129784
# min                        0.000000                     0.000000
# ...

# %%
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Проверяем на наличие явных дубликатов

# %%
data_train.duplicated().sum()
# Out:
# 0

# %%
data_test.duplicated().sum()
# Out:
# 0

# %%
data_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Пропуски в данных

# %% [markdown]
# Согласно выводу метода info(), в данных имеются пропуски, но оценить их количество достаточно сложно.
# Лучше написать функцию, которая сделает оценку за нас.

# %%
def count_isna(df):
    for column in df.columns:
        print('Количество пропусков в каждом столбце')    
        # так как в дальнейшем нужно будет принимать решение, как поступить с пропусками, то лучше сразу оценить
        # не фактическое кол-во пропусков, а относительно всех записей в столбце
        #print(df.isna().sum()) 
        print(df.isna().mean())

# %%
count_isna(data_train)
# Out:
# Количество пропусков в каждом столбце
# date                                          0.000000
# final.output.concentrate_ag                   0.000071
# final.output.concentrate_pb                   0.000071
# final.output.concentrate_sol                  0.014913
# final.output.concentrate_au                   0.000000
#                                                 ...
# secondary_cleaner.state.floatbank5_a_level    0.000071
# secondary_cleaner.state.floatbank5_b_air      0.000071
# secondary_cleaner.state.floatbank5_b_level    0.000071
# secondary_cleaner.state.floatbank6_a_air      0.000141
# secondary_cleaner.state.floatbank6_a_level    0.000071
# Length: 87, dtype: float64
# Количество пропусков в каждом столбце
# date                                          0.000000
# final.output.concentrate_ag                   0.000071
# final.output.concentrate_pb                   0.000071
# final.output.concentrate_sol                  0.014913
# ...

# %%
count_isna(data_test)
# Out:
# Количество пропусков в каждом столбце
# date                                          0.000000
# primary_cleaner.input.sulfate                 0.000756
# primary_cleaner.input.depressant              0.000945
# primary_cleaner.input.feed_size               0.000000
# primary_cleaner.input.xanthate                0.000756
# primary_cleaner.state.floatbank8_a_air        0.000000
# primary_cleaner.state.floatbank8_a_level      0.000000
# primary_cleaner.state.floatbank8_b_air        0.000000
# primary_cleaner.state.floatbank8_b_level      0.000000
# primary_cleaner.state.floatbank8_c_air        0.000000
# primary_cleaner.state.floatbank8_c_level      0.000000
# primary_cleaner.state.floatbank8_d_air        0.000000
# primary_cleaner.state.floatbank8_d_level      0.000000
# rougher.input.feed_ag                         0.000000
# rougher.input.feed_pb                         0.000000
# rougher.input.feed_rate                       0.000567
# ...

# %%
count_isna(data_full)
# Out:
# Количество пропусков в каждом столбце
# date                                          0.000000
# final.output.concentrate_ag                   0.000051
# final.output.concentrate_pb                   0.000051
# final.output.concentrate_sol                  0.010854
# final.output.concentrate_au                   0.000000
#                                                 ...
# secondary_cleaner.state.floatbank5_a_level    0.000051
# secondary_cleaner.state.floatbank5_b_air      0.000051
# secondary_cleaner.state.floatbank5_b_level    0.000051
# secondary_cleaner.state.floatbank6_a_air      0.000103
# secondary_cleaner.state.floatbank6_a_level    0.000051
# Length: 87, dtype: float64
# Количество пропусков в каждом столбце
# date                                          0.000000
# final.output.concentrate_ag                   0.000051
# final.output.concentrate_pb                   0.000051
# final.output.concentrate_sol                  0.010854
# ...

# %% [markdown]
# Какого-то существенного процента пропусков в данных не обнаружено, можно дропнуть строки с пустыми значениями и пересчитать индексацию для каждого из набора данных. А можно заполнить соседним значением, в задании говорится, что соседние по времени параметры часто похожи. Можем тогда применить метод заполнения следующим непропущенным значением.

# %%
cl_data_train = data_train.fillna(method='ffill')
cl_data_train.isna().mean()
# Out:
# date                                          0.0
# final.output.concentrate_ag                   0.0
# final.output.concentrate_pb                   0.0
# final.output.concentrate_sol                  0.0
# final.output.concentrate_au                   0.0
#                                              ...
# secondary_cleaner.state.floatbank5_a_level    0.0
# secondary_cleaner.state.floatbank5_b_air      0.0
# secondary_cleaner.state.floatbank5_b_level    0.0
# secondary_cleaner.state.floatbank6_a_air      0.0
# secondary_cleaner.state.floatbank6_a_level    0.0
# Length: 87, dtype: float64

# %%
cl_data_test = data_test.fillna(method='ffill')
cl_data_test.isna().mean()
# Out:
# date                                          0.0
# primary_cleaner.input.sulfate                 0.0
# primary_cleaner.input.depressant              0.0
# primary_cleaner.input.feed_size               0.0
# primary_cleaner.input.xanthate                0.0
# primary_cleaner.state.floatbank8_a_air        0.0
# primary_cleaner.state.floatbank8_a_level      0.0
# primary_cleaner.state.floatbank8_b_air        0.0
# primary_cleaner.state.floatbank8_b_level      0.0
# primary_cleaner.state.floatbank8_c_air        0.0
# primary_cleaner.state.floatbank8_c_level      0.0
# primary_cleaner.state.floatbank8_d_air        0.0
# primary_cleaner.state.floatbank8_d_level      0.0
# rougher.input.feed_ag                         0.0
# rougher.input.feed_pb                         0.0
# rougher.input.feed_rate                       0.0
# rougher.input.feed_size                       0.0
# rougher.input.feed_sol                        0.0
# rougher.input.feed_au                         0.0
# ...

# %% [markdown]
# ### Проверка правильности расчёта эффективности обогащения

# %% [markdown]
# Эффективность обогащения расчитывается по формуле:
# recovery = (C * (F - T)) / (F * (C - T)) * 100%
#   * C - доля золота в концентрате после флотации/очистки;
#   * F - доля золота в сырье/концентрате до флотации/очистки;
#   * T - доля золота в отвальных хвостах после флотации/очистки.

# %%
orig_recovery = data_train['rougher.output.recovery']

calculated_recovery = (data_train['rougher.output.concentrate_au'] * (data_train['rougher.input.feed_au'] - 
                    data_train['rougher.output.tail_au']) / data_train['rougher.input.feed_au'] / 
                       (data_train['rougher.output.concentrate_au'] - data_train['rougher.output.tail_au']) * 100)

print('Эффективность обогащения чернового концентрата', calculated_recovery.head(5), sep='\n')
print('Абсолютная средняя ошибка =', mean_absolute_error(orig_recovery, calculated_recovery))
# Out:
# Эффективность обогащения чернового концентрата
# 0    87.107763
# 1    86.843261
# 2    86.842308
# 3    87.226430
# 4    86.688794
# dtype: float64
# Абсолютная средняя ошибка = 1.0748911125799084e-14

# %% [markdown]
# На сколько мы видим, MAE имеет очень малое значение. Это значит, что расчетное значение `rougher.output.recovery` совпадает с данными из исходного столбца.

# %% [markdown]
# ### Анализ признаков в обучающей и тестовой выборках

# %%
print(data_train.columns.shape)
print(data_train.columns)
# Out:
# (87,)
# Index(['date', 'final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb',
#        'final.output.tail_sol', 'final.output.tail_au',
#        'primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.output.concentrate_ag',
#        'primary_cleaner.output.concentrate_pb',
#        'primary_cleaner.output.concentrate_sol',
#        'primary_cleaner.output.concentrate_au',
#        'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb',
#        'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
# ...

# %%
print(data_test.columns.shape)
print(data_test.columns)
# Out:
# (53,)
# Index(['date', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
# ...

# %%
# разница в 34 признака, можно посмотреть, какие именно отсуствуют
# выделяем признаки, которых нет в выборке test:
missed_features = set(data_train.columns) - set(data_test.columns)

# проверяем инф-юо признаках, которых нет в выборке test:
data_train[missed_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 34 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   primary_cleaner.output.tail_au                      14149 non-null  float64
#  1   final.output.tail_ag                                14149 non-null  float64
#  2   primary_cleaner.output.concentrate_sol              13863 non-null  float64
#  3   primary_cleaner.output.concentrate_pb               14063 non-null  float64
#  4   rougher.calculation.sulfate_to_au_concentrate       14148 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   rougher.output.concentrate_ag                       14149 non-null  float64
# ...

# %% [markdown]
# В тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков (`rougher.output.recovery` и `final.output.recovery`). Нам это известно из информации к заданию, причина - некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Скорее всего столбцы этапов `rougher.output`, `rougher.calculation`, `final.output`, `primary_cleaner.output` и `secondary_cleaner.output` отсутсвуют в тестовой выборке, так как заполняются после завершения тех. процессов.
# *Заметки:*
#   * в test нет 34 признаков, это 30 типа `output` (параметры продукта) и 4 типа `calculation` (расчётные характеристики);
#   * в дальнейшем необходимо в датасет test добавить целевые признаки из датасета full, и на этапе обучения из датасета train удалить признаки, которых нет в test.

# %% [markdown]
# ### Определение ключевых признаков для обучения модели и их подготовка

# %%
# используем все столбцы кроме даты (date), так как не несет ценности для обучения
#features_columns = cl_data_test.columns[1:]
features_columns_df = cl_data_test.drop(['date'], axis=1)
features_columns = features_columns_df.columns

# для предсказания одного из целевых признакв - rougher.output.recovery - используем данные из стобцов, 
# относящихся к флотации (rougher)
#rougher_features_columns = set(features_columns[12:34]) 
rougher_features_columns = set(features_columns_df.loc[:, 'rougher.input.feed_ag':'rougher.state.floatbank10_f_level'].columns) 

# для расчёта второго целевого признака - final.output.recovery - будем использовать все столбцы из тестовой выборки
final_features_columns = set(features_columns) 

# посмотрим, какие колонки будут участвовать в предсказании каждого целевого признака
print('Пространство признаков для прогнозирования "rougher.output.recovery": ', len(rougher_features_columns), rougher_features_columns, sep='\n')
print('-----------------------------------------------------------------------------------------------------------')
print('Пространство признаков для прогнозирования "final.output.recovery": ', len(final_features_columns), final_features_columns, sep='\n')
# Out:
# Пространство признаков для прогнозирования "rougher.output.recovery":
# 22
# {'rougher.state.floatbank10_b_air', 'rougher.input.feed_rate', 'rougher.state.floatbank10_e_air', 'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_c_air', 'rougher.state.floatbank10_d_level', 'rougher.input.floatbank11_sulfate', 'rougher.input.floatbank10_xanthate', 'rougher.state.floatbank10_f_level', 'rougher.state.floatbank10_d_air', 'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate', 'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_level', 'rougher.input.feed_size', 'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_e_level', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_ag', 'rougher.state.floatbank10_a_air'}
# -----------------------------------------------------------------------------------------------------------
# Пространство признаков для прогнозирования "final.output.recovery":
# ...

# %% [markdown]
# Нужно визуально оценить распределение целевого признака

# %%
plt.figure(figsize=[10,8])

plt.hist(cl_data_train['rougher.output.recovery'], bins=90)

plt.xlim([0, 100])
plt.ylim([0, 900])

plt.xlabel("Эффективность обогащения чернового концентрата ")
plt.ylabel("Количество результатов")

plt.title("Гистограмма распределения по эффективности обогащения")
plt.show()

# %% [markdown]
# Достаточно много нулевых значений, проверим долю золота, так как именно оно нас интересует

# %%
plt.figure(figsize=[10,8])

plt.hist(cl_data_train['rougher.output.concentrate_au'], bins=100)

plt.xlim([0, 100])
plt.ylim([0, 900])

plt.xlabel("Эффективность обогащения чернового концентрата ")
plt.ylabel("Количество результатов")

plt.title("Доля золота в концентрате до очистки")
plt.show()

# %% [markdown]
# Нулевых значений также много, нужно посмотреть, что и себя представляют указанные данные

# %%
cl_data_train[cl_data_train['rougher.output.recovery'] < 1].head(5)
# Out:
#                    date  final.output.concentrate_ag  \
# 45  2016-01-16 21:00:00                     4.566664
# 46  2016-01-16 22:00:00                     4.577832
# 47  2016-01-16 23:00:00                     4.591462
# 48  2016-01-17 00:00:00                     5.296830
# 49  2016-01-17 02:00:00                     8.162896
#
#     final.output.concentrate_pb  final.output.concentrate_sol  \
# 45                    10.406178                      4.588698
# 46                    10.691605                      5.274175
# 47                    10.628846                      5.688961
# 48                    10.597469                      5.688961
# 49                     8.877528                      5.688961
#
#     final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 45                    46.614456              68.403877             10.705777
# 46                    46.250638              70.675633             10.728531
# ...

# %%
cl_data_train[cl_data_train['rougher.output.concentrate_au'] < 1].head(5)
# Out:
#                    date  final.output.concentrate_ag  \
# 45  2016-01-16 21:00:00                     4.566664
# 46  2016-01-16 22:00:00                     4.577832
# 47  2016-01-16 23:00:00                     4.591462
# 48  2016-01-17 00:00:00                     5.296830
# 49  2016-01-17 02:00:00                     8.162896
#
#     final.output.concentrate_pb  final.output.concentrate_sol  \
# 45                    10.406178                      4.588698
# 46                    10.691605                      5.274175
# 47                    10.628846                      5.688961
# 48                    10.597469                      5.688961
# 49                     8.877528                      5.688961
#
#     final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 45                    46.614456              68.403877             10.705777
# 46                    46.250638              70.675633             10.728531
# ...

# %% [markdown]
# Видно, что вместо значений проставлены нули. Нужно посчитать какой процент от всех значений, если небольшой - удалить.

# %%
def zeros_count(df, column):
    zeros = df[df[column] == 0][column].count()
    percent = zeros / df.shape[0]
    print('Количество нулевых значений:', zeros)
    print('Процент нулевых значений от общего числа строк:', percent)

# %%
zeros_count(cl_data_train, 'rougher.output.recovery')
# Out:
# Количество нулевых значений: 297
# Процент нулевых значений от общего числа строк: 0.02099088274789738

# %% [markdown]
# Процент небольшой, к тому же данных нет именно в колонках, относящихся к процессу флотации (rougher). Удаляем.

# %%
cl_data_train = cl_data_train.drop(cl_data_train[cl_data_train['rougher.output.recovery'] == 0].index)
cl_data_train[cl_data_train['rougher.output.recovery'] < 1].head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# Отлично! От нулевых значений в одном из целевых признаков избавились, переходим ко второму.

# %%
# Построим гистограмму эффективности финального концентрата с обработанными данными
plt.figure(figsize=[12,9])

plt.hist(cl_data_train['final.output.recovery'], bins=100)

plt.xlim([0, 110])
plt.ylim([0, 800])

plt.xlabel("Эффективность обогащения финального концентрата ")
plt.ylabel("Количество результатов")

plt.title("Гистограмма распределения по эффективности обогащения")
plt.show()

# %%
cl_data_train[cl_data_train['final.output.recovery'] < 1].head(5)
# Out:
#                      date  final.output.concentrate_ag  \
# 644   2016-02-13 11:00:00                     0.000000
# 1057  2016-03-02 11:00:00                     4.637727
# 1193  2016-03-11 10:00:00                     0.000000
# 1194  2016-03-11 11:00:00                     0.000000
# 1195  2016-03-11 12:00:00                     0.000000
#
#       final.output.concentrate_pb  final.output.concentrate_sol  \
# 644                      0.000000                      0.000000
# 1057                    12.557566                      7.821058
# 1193                     0.000000                      0.000000
# 1194                     0.000000                      0.000000
# 1195                     0.000000                      0.000000
#
#       final.output.concentrate_au  final.output.recovery  \
# 644                      0.000000               0.000000
# 1057                    41.529734               0.463711
# 1193                     0.000000               0.000000
# ...

# %%
zeros_count(cl_data_train, 'final.output.recovery')
# Out:
# Количество нулевых значений: 57
# Процент нулевых значений от общего числа строк: 0.00411492925209356

# %%
cl_data_train = cl_data_train.drop(cl_data_train[cl_data_train['final.output.recovery'] == 0].index)
cl_data_train[cl_data_train['final.output.recovery'] < 1].head(5)
# Out:
#                       date  final.output.concentrate_ag  \
# 1057   2016-03-02 11:00:00                     4.637727
# 11993  2018-05-02 17:59:59                     5.644008
# 12277  2018-05-15 04:59:59                     0.010000
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 1057                     12.557566                      7.821058
# 11993                     6.994057                      7.987903
# 12277                     0.010000                      0.010000
#
#        final.output.concentrate_au  final.output.recovery  \
# 1057                     41.529734               0.463711
# 11993                    50.518813               0.430264
# 12277                     0.010000               0.168611
#
#        final.output.tail_ag  final.output.tail_pb  final.output.tail_sol  \
# 1057              11.388568              1.893716               7.735606
# 11993              8.709877              0.987726               8.533550
# ...

# %%
cl_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13795 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                13795 non-null  object
#  1   final.output.concentrate_ag                         13795 non-null  float64
#  2   final.output.concentrate_pb                         13795 non-null  float64
#  3   final.output.concentrate_sol                        13795 non-null  float64
#  4   final.output.concentrate_au                         13795 non-null  float64
#  5   final.output.recovery                               13795 non-null  float64
#  6   final.output.tail_ag                                13795 non-null  float64
#  7   final.output.tail_pb                                13795 non-null  float64
# ...

# %% [markdown]
# Получился ровный датафрейм, который не содержит нулевые значения в важных для будущей модели колонках

# %% [markdown]
# ### Выводы
# 1) Дубликаты не обнаружены;
# 2) В результате оценки имеющихся данных были обнаружены пропуски, которые мы зполнили ближайшим непустым значением;
# 3) Посчитали эффективность обогащения смеси после флотации. Сравнили с показателями, указанными в исходных данных. Согласно очень маленькой MAE （1.0748911125799084e-14）пришли к выводу о корректности предоставленных данных;
# 4) Количественная разница между признаками в обучающей выборке и тестовой составила 34 признака (колонки). По сути это 30 признаков, относящиеся к продукту, и 4 - к расчётным значениям. Важное замечание, что в течтовой выборке отсутствуют целевые признаки, их нужно будет добавить в дальнейшем;
# 5) Определеили пространство признаков для каждого из целевых признаков (`rougher.output.recovery` и `final.output.recovery`), избавились от значений, просто заполненных нулями, так как они могли негативно повлиять на работу нашей модели.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Анализ концентрации Au, Ag, Pb на разных этапах очистки

# %% [markdown]
# Отличный вариант для оценки данных - визуализация. Построим гистограммы концентрации веществ после каждого шага.
# По идее концентрации должны возрастать, вот это и проверим.

# %%
# Золото
plt.figure(figsize=[12,9])

plt.hist(cl_data_train['final.output.concentrate_au'], bins=100, label = 'final.output', alpha=.5)
plt.hist(cl_data_train['primary_cleaner.output.concentrate_au'], bins=100, label = 'primary_cleaner.output', alpha=.5)
plt.hist(cl_data_train['rougher.output.concentrate_au'], bins=100, label = 'rougher.output', alpha=.5)
plt.hist(cl_data_train['rougher.input.feed_au'], bins=100, label = 'rougher.input', alpha=.5)

plt.xlim([0, 60])
plt.ylim([0, 1500])

plt.xlabel("Концентрация золота на каждом этапе")
plt.ylabel("Количество результатов")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Гистограмма распределения концентрации золота")
plt.show()

# %% [markdown]
# Очевидно, что концентрация золота возрастает от этапа к этапу. Это хорошо, так как главная задача технологического процесса состоит в максимальном повышении концентрации золота.

# %%
# Серебро
plt.figure(figsize=[12,9])

plt.hist(cl_data_train['final.output.concentrate_ag'], bins=110, label = 'final.output', alpha=.5)
plt.hist(cl_data_train['primary_cleaner.output.concentrate_ag'], bins=110, label = 'primary_cleaner.output', alpha=.5)
plt.hist(cl_data_train['rougher.output.concentrate_ag'], bins=110, label = 'rougher.output', alpha=.5)
plt.hist(cl_data_train['rougher.input.feed_ag'], bins=100, label = 'rougher.input', alpha=.5)

plt.xlim([0, 25])
plt.ylim([0, 700])

plt.xlabel("Концентрация серебра на каждом этапе")
plt.ylabel("Количество результатов")

plt.legend(loc='upper right', fontsize='x-large')

plt.title("Гистограмма распределения концентрации серебра")
plt.show()

# %% [markdown]
# Интересная картина, на графике изображения находятся справа налево, то есть концентрацция серебра снижвается от этапа к этапы. Вероятно, это связано с отфильтровыванием нецелевых веществ.

# %%
# Свинец
plt.figure(figsize=[12,10])

plt.hist(cl_data_train['final.output.concentrate_pb'], bins=100, label = 'final.output', alpha=.5)
plt.hist(cl_data_train['primary_cleaner.output.concentrate_pb'], bins=100, label = 'primary_cleaner.output', alpha=.5)
plt.hist(cl_data_train['rougher.output.concentrate_pb'], bins=100, label = 'rougher.output', alpha=.5)
plt.hist(cl_data_train['rougher.input.feed_pb'], bins=100, label = 'rougher.input', alpha=.5)

plt.xlim([0, 20])
plt.ylim([0, 800])

plt.xlabel("Концентрация свинца на каждом этапе")
plt.ylabel("Количество результатов")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Гистограмма распределения концентрации свинца")
plt.show()

# %% [markdown]
# Из-за наложения графиков друг на друга трудно оценивать, но приходим к выводу, что концентрация свинца возрасла к концу технологического процесса.

# %% [markdown]
# ### Сравнение распределения размеров гранул сырья

# %%
# перед флотацией размер гранул в обучающей и тестовой выборках
plt.figure(figsize=[13,10])

plt.hist(cl_data_train['rougher.input.feed_size'], density=True, bins=220, label = 'Train rougher.input.feed_size', alpha=.55)
plt.hist(cl_data_test['rougher.input.feed_size'], density=True, bins=220, label = 'Test rougher.input.feed_size', alpha=.55)

plt.xlim([0, 400])
plt.ylim([0, 0.1])

plt.xlabel("Размер гранул сырья, меш")
plt.ylabel("Частота появления результатов")

plt.legend(loc='upper right', fontsize='x-large')

plt.title("Гистограмма распределения гранул сырья перед флотацией")
plt.show()

# %% [markdown]
# В целом, видно нормальное распеделение значений со смещение влево для обеих выборок, после отметки 110 видим много выбросов.

# %%
# перед первичной очисткой размер гранул в обучающей и тестовой выборках
plt.figure(figsize=[12,9])

plt.hist(cl_data_train['primary_cleaner.input.feed_size'], density=True, bins=100, label = 'Train primary_cleaner.input.feed_size', alpha=.5)
plt.hist(cl_data_test['primary_cleaner.input.feed_size'], density=True, bins=100, label = 'Test primary_cleaner.input.feed_size', alpha=.5)

#plt.xlim([0, 16])
#plt.ylim([0, 1000])

plt.xlabel("Размер гранул сырья")
plt.ylabel("Частота появления результатов")

plt.legend(loc='upper right', fontsize='x-large')

plt.title("Гистограмма распределения гранул сырья перед первичной очисткой")
plt.show()

# %% [markdown]
# Как видно из графиков выше, после флотации распределение размеров гранул после флотации нормализовалось.
# Далее подготавливаем столбцы с концентрациями всех интресующих нас элементов в обучающей выборке по этапам технологического процесса и строим по получнным данным гистограмму.

# %%
feed_input_concentrate_sum_train = (cl_data_train['rougher.input.feed_au'] + 
                                    cl_data_train['rougher.input.feed_ag'] + 
                                    cl_data_train['rougher.input.feed_pb'] + 
                                    cl_data_train['rougher.input.feed_sol'])
rougher_output_concentrate_sum_train = (cl_data_train['rougher.output.concentrate_au'] + 
                                        cl_data_train['rougher.output.concentrate_ag'] + 
                                        cl_data_train['rougher.output.concentrate_pb'] + 
                                        cl_data_train['rougher.output.concentrate_sol'])
primary_cleaner_output_concentrate_sum_train = (cl_data_train['primary_cleaner.output.concentrate_au'] +
                                                cl_data_train['primary_cleaner.output.concentrate_ag'] +
                                                cl_data_train['primary_cleaner.output.concentrate_pb'] +
                                                cl_data_train['primary_cleaner.output.concentrate_sol'])
final_output_concentrate_sum_train = (cl_data_train['final.output.concentrate_au'] + 
                                      cl_data_train['final.output.concentrate_ag'] + 
                                      cl_data_train['final.output.concentrate_pb'] + 
                                      cl_data_train['final.output.concentrate_sol'])

# %%
plt.figure(figsize=[12,9])

plt.hist(rougher_output_concentrate_sum_train, bins=100, label = 'rougher_output', alpha=.4)
plt.hist(feed_input_concentrate_sum_train, bins=100, label = 'rougher.input.feed', alpha=.5)
plt.hist(primary_cleaner_output_concentrate_sum_train, bins=100, label = 'primary_cleaner_output', alpha=.5)
plt.hist(final_output_concentrate_sum_train, bins=100, label = 'final_output', alpha=.4)

plt.xlim([0, 100])
plt.ylim([0, 2000])

plt.xlabel("Сум. концентраця")
plt.ylabel("Количество результатов")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Гистограмма распределения концентраций на разных этапах очистки")
plt.show()

# %% [markdown]
# Видно, что распределение на каждом этапе похоже на нормальное, а суммарная концентраия интересующих нас веществ на выходе возрасла.
# Для первичной очистки в районе 0 обнаружено некоторое количество значений, с которыми нужно разобраться.

# %%
# попробуем посчитать сколько именно нулевых значений
au = cl_data_train[cl_data_train['primary_cleaner.output.concentrate_au'] == 0]['primary_cleaner.output.concentrate_au'].count()
ag = cl_data_train[cl_data_train['primary_cleaner.output.concentrate_ag'] == 0]['primary_cleaner.output.concentrate_ag'].count()
pb = cl_data_train[cl_data_train['primary_cleaner.output.concentrate_pb'] == 0]['primary_cleaner.output.concentrate_pb'].count()

print('Нулевые значния для золота, серебра, свинца:', au, ag, pb, 'Сумма:', au + ag + pb, sep='\n')
# Out:
# Нулевые значния для золота, серебра, свинца:
# 70
# 70
# 75
# Сумма:
# 215

# %% [markdown]
# Понятно, что это аномалия в данных, нулевые значения можно удалить

# %%
cl_data_train = cl_data_train.drop(cl_data_train[cl_data_train['primary_cleaner.output.concentrate_au'] == 0].index)
cl_data_train = cl_data_train.drop(cl_data_train[cl_data_train['primary_cleaner.output.concentrate_ag'] == 0].index)
cl_data_train = cl_data_train.drop(cl_data_train[cl_data_train['primary_cleaner.output.concentrate_pb'] == 0].index)

au = cl_data_train[cl_data_train['primary_cleaner.output.concentrate_au'] == 0]['primary_cleaner.output.concentrate_au'].count()
ag = cl_data_train[cl_data_train['primary_cleaner.output.concentrate_ag'] == 0]['primary_cleaner.output.concentrate_ag'].count()
pb = cl_data_train[cl_data_train['primary_cleaner.output.concentrate_pb'] == 0]['primary_cleaner.output.concentrate_pb'].count()

print('Нулевые значния для золота, серебра, свинца:', au, ag, pb, 'Сумма:', au + ag + pb, sep='\n')
# Out:
# Нулевые значния для золота, серебра, свинца:
# 0
# 0
# 0
# Сумма:
# 0

# %% [markdown]
# ### Выводы
# 1) Провели анализ золота, серебра и свинца на каждом этапе технологического процесса. Концентрация золота стабильно растёт, свинца тоже, а вот себера снижается. Вероятно, из-за отведения серебра по мере увеличения концентрации золота;
# 2) Проверили гранулы сырья на обучающей и тестовых выборках, после флотации распределение размров гранул нормализовалось;
# 3) Суммарная концентрация всех веществ по мере прохождения технологического процесса возрастает;
# 4) В данных были найдены нулевые значения (аномалии) и обработаны, данные готовы к обучению.

# %% [markdown]
# ## Разработка модели

# %% [markdown]
# ### Подготовка пространства признаков и целевого признака на основе выборок

# %%
# Для формирования принаковых пространств пойдём от обратного, наиболее полного набора данных

# пространство признаков для final.output.recovery
train_features_dataset_final = cl_data_train.drop((set(cl_data_train.columns) - final_features_columns), axis=1)
print('Пространство признаков для final.output.recovery:', train_features_dataset_final.columns, sep='\n')
print()

# пространство признаков для rougher.output.recovery
train_features_dataset_rougher = train_features_dataset_final.drop((set(train_features_dataset_final.columns) - rougher_features_columns), axis=1)
print('Пространство признаков для rougher.output.recovery:', train_features_dataset_rougher.columns, sep='\n')
# Out:
# Пространство признаков для final.output.recovery:
# Index(['primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
# ...

# %%
# целевой признак в обучающей выборке
train_target_dataset_rougher = cl_data_train['rougher.output.recovery']
train_target_dataset_final = cl_data_train['final.output.recovery']

# %%
# целевой признак в тестовой выборке
test_features_final = cl_data_test.drop('date', axis=1)
test_features_rougher = test_features_final.drop((set(test_features_final.columns) - rougher_features_columns), axis=1)

# %%
for sample in [train_target_dataset_rougher, train_target_dataset_final]:
    print(sample.shape)
# Out:
# (13720,)
# (13720,)

# %%
print(test_features_final.shape, test_features_rougher.shape)
# Out:
# (5290, 52) (5290, 22)

# %% [markdown]
# ### Выбор модели и оптимизация гиперпараметров

# %% [markdown]
# Напишем несколько функций, которые будут считать новую метрику качества `sMAPE`, а также её финальную версию `sMAPE_final`

# %%
# согласно заданию, метрика принимает на вход фактические значения и предсказанные,
# сравнивает их и считает разницу, дельту
def sMAPE(val_true, val_pred):
    delta = np.mean(abs(val_true - val_pred)/((abs(val_true)+abs(val_pred))/2))*100
    return delta

# %%
# формула согласно условию задачи
def sMAPE_summary(sMAPE_rougher,sMAPE_final):
    return (0.25*sMAPE_rougher + 0.75*sMAPE_final)

# %%
# вводим собственную метрику через make_scorer, чтобы указать её в кросс-валидации, тем самым автоматизировать.
# функция make_scorer преобразует метрики в вызываемые объекты, которые можно использовать для оценки модели.
score = make_scorer(sMAPE, greater_is_better = False)

# %%
# для оптимизации процесса обработки данных используем make_pipeline для случайного леса, дерева решений и регрессии.
# pipeline - это конвейер для объединения нескольких оценщиков в один.
model_rfr = make_pipeline(StandardScaler(), RandomForestRegressor())
model_dtr = make_pipeline(StandardScaler(), DecisionTreeRegressor())
model_lr = make_pipeline(StandardScaler(), LinearRegression())

# %%
# задаём гиперпараметры для моделей, которые будут перебираться в поисках наилучшего результата:
parameters_rfr = {'randomforestregressor__n_estimators':[1,150],
                  'randomforestregressor__max_depth':[1,10],
                  'randomforestregressor__random_state':[12345]}

parameters_dtr = {'decisiontreeregressor__max_depth':[1,10]}

parameters_lr = {'linearregression__normalize':[False]}

# %%
# используем агрегатор GridSearchCV для перебора гиперпараметров и для кросс-валидации:
grid_rougher_rfr = GridSearchCV(model_rfr, param_grid=parameters_rfr, cv=5, scoring=score)
grid_final_rfr = GridSearchCV(model_rfr, param_grid=parameters_rfr, cv=5, scoring=score)

grid_rougher_dtr = GridSearchCV(model_dtr, param_grid=parameters_dtr, cv=5, scoring=score)
grid_final_dtr = GridSearchCV(model_dtr, param_grid=parameters_dtr, cv=5, scoring=score)

grid_rougher_lr = GridSearchCV(model_lr, param_grid=parameters_lr, scoring=score)
grid_final_lr = GridSearchCV(model_lr, param_grid=parameters_lr, scoring=score)

# %%
# %%time

# обучение моделей будет выглядеть следующим образом:
grid_rougher_rfr.fit(train_features_dataset_rougher, train_target_dataset_rougher)
grid_final_rfr.fit(train_features_dataset_final, train_target_dataset_final)

grid_rougher_dtr.fit(train_features_dataset_rougher, train_target_dataset_rougher)
grid_final_dtr.fit(train_features_dataset_final, train_target_dataset_final)

grid_rougher_lr.fit(train_features_dataset_rougher, train_target_dataset_rougher)
grid_final_lr.fit(train_features_dataset_final, train_target_dataset_final)
# Out:
# CPU times: user 7min 49s, sys: 3.81 s, total: 7min 53s
# Wall time: 7min 53s
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('linearregression',
#                                         LinearRegression())]),
#              param_grid={'linearregression__normalize': [False]},
#              scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
# определяем лучшую из моделей для 2 целевых признаков: 
best_score_rougher_rfr = grid_rougher_rfr.best_score_
best_score_final_rfr = grid_final_rfr.best_score_

best_score_rougher_dtr = grid_rougher_dtr.best_score_
best_score_final_dtr = grid_final_dtr.best_score_

best_score_rougher_lr = grid_rougher_lr.best_score_
best_score_final_lr = grid_final_lr.best_score_

# выводим значения на экран
print('по модели RandomForestRegressor лучший результат rougher =', best_score_rougher_rfr)
print('по модели DecisionTreeRegressor лучший результат rougher =', best_score_rougher_dtr)
print('по модели LinearRegression лучший результат rougher =', best_score_rougher_lr)
print()
print('по модели RandomForestRegressor лучший результат final =', best_score_final_rfr)
print('по модели DecisionTreeRegressor лучший результат final =', best_score_final_dtr)
print('по модели LinearRegression лучший результат final =', best_score_final_lr)
# Out:
# по модели RandomForestRegressor лучший результат rougher = -6.844767793457803
# по модели DecisionTreeRegressor лучший результат rougher = -7.958148016259497
# по модели LinearRegression лучший результат rougher = -6.673495949068753
#
# по модели RandomForestRegressor лучший результат final = -9.456745018459076
# по модели DecisionTreeRegressor лучший результат final = -9.746631543650489
# по модели LinearRegression лучший результат final = -10.94756197745754

# %%
# вычисляем summary sMAPE для каждой модели:
sum_smape_rfr = sMAPE_summary(best_score_rougher_rfr, best_score_final_rfr)
print('по модели RandomForestRegressor итоговое sMAPE =', sum_smape_rfr)

sum_smape_dtr = sMAPE_summary(best_score_rougher_dtr, best_score_final_dtr)
print('по модели DecisionTreeRegressor итоговое sMAPE =', sum_smape_dtr)

sum_smape_lr = sMAPE_summary(best_score_rougher_lr, best_score_final_lr)
print('по модели LinearRegression итоговое sMAPE =', sum_smape_lr)
# Out:
# по модели RandomForestRegressor итоговое sMAPE = -8.803750712208759
# по модели DecisionTreeRegressor итоговое sMAPE = -9.299510661802742
# по модели LinearRegression итоговое sMAPE = -9.879045470360342

# %% [markdown]
# По результатам всех вычислений выше видно, что лучший рзультат предсказаний у `RandomForestRegressor`, значит вычисления на тестовой выборке производим с помощью этой модели.

# %%
# выше я указывал, что в тестовой выборке нет целевых признаков, их нужно добавить из full датасета
test_frame_for_target = cl_data_test.merge(data_full.loc[:,['date', 'rougher.output.recovery', 'final.output.recovery']], on = 'date')

# тогда целевые датасеты
target_test_rougher = test_frame_for_target['rougher.output.recovery']
target_test_final = test_frame_for_target['final.output.recovery']

# получаем предсказания от обученной модели
test_rogher = grid_rougher_rfr.predict(test_features_rougher) 
test_final = grid_final_rfr.predict(test_features_final)

# вычисляем sMAPE
rouger_smape_test = sMAPE(target_test_rougher, test_rogher)
final_smape_test = sMAPE(target_test_final, test_final)

# вычисляем финальную sMAPE
final_sum_smape = sMAPE_summary(rouger_smape_test, final_smape_test)
print('Симметричная средняя абсолютная процентная ошибка на тестовой выборке =', round(final_sum_smape,3))
# Out:
# Симметричная средняя абсолютная процентная ошибка на тестовой выборке = 9.165

# %% [markdown]
# ### Проверка на вменяемость

# %%
for strategy in ['mean', 'median']:
    dummy_rougher = DummyRegressor(strategy=strategy)
    dummy_final = DummyRegressor(strategy=strategy)
    
    dummy_rougher.fit(train_features_dataset_rougher, train_target_dataset_rougher)
    dummy_final.fit(train_features_dataset_final, train_target_dataset_final)
    
    rougher = dummy_rougher.predict(test_features_rougher)
    final = dummy_final.predict(test_features_final)
    
    final_smape = sMAPE_summary(sMAPE(target_test_rougher, rougher),
                                   sMAPE(target_test_final, final))

    print('Для стратегии', strategy, 'итоговая sMAPE =', round(final_smape,3))
# Out:
# Для стратегии mean итоговая sMAPE = 9.829
# Для стратегии median итоговая sMAPE = 9.442

# %% [markdown]
# Метрики константной модели, что для среднего, что для медианного значения оказались хуже, чем у `RandomForestRegressor`, таким образом, разработанная нами модель прошла тест на адекватность.

# %% [markdown]
# ### Выводы
# 1) Для автоматизации процесса использовали функцию собственой метрики и pipeline, в качестве конвейера;
# 2) Лучшая модель - RandomForestRegressor, показатель final sMAPE на обучающей выборке = -8.92, на тестовой = 9.206;
# 3) Выбранная модель проходит проверку на адекватность: 9.206 у RFR, против 9.441 у DummyRegressor.

# %% [markdown]
# ## Общий вывод
# 1) Имеющиеся исходные данные были проверены и предобработаны;
# 2) Посчитали эффективность обогащения смеси после флотации. Сравнили с показателями, указанными в исходных данных. Согласно очень маленькой MAE （1.0748911125799084e-14）пришли к выводу о корректности предоставленных данных;
# 3) На этапе подготовки данных определеили пространство признаков для каждого из целевых признаков (rougher.output.recovery и final.output.recovery), избавились от значений, просто заполненных нулями, так как они могли негативно повлиять на работу нашей модели.
# 4) Провели анализ золота, серебра и свинца на каждом этапе технологического процесса. Концентрация золота стабильно растёт, свинца тоже, а вот себера снижается. Вероятно, из-за отведения серебра по мере увеличения концентрации золота;
# 5) Проверили гранулы сырья на обучающей и тестовых выборках, после флотации распределение размров гранул нормализовалось;
# 6) Суммарная концентрация всех веществ по мере прохождения технологического процесса возрастает;
# 7) В данных были найдены нулевые значения (аномалии) и обработаны, данные готовы к обучению.
# 8) Для автоматизации процесса подбора модели использовали собственую функцию оценки метрики и pipeline, в качестве конвейера, а также GridSearchCV;
# 9) Лучшая модель - RandomForestRegressor, показатель final sMAPE на обучающей выборке = -8.92, на тестовой = 9.206;
# 10) Выбранная модель проходит проверку на адекватность: 9.206 у RFR, против 9.441 у DummyRegressor.
